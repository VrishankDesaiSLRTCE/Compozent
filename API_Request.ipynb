# %% [markdown]
# <a href="https://colab.research.google.com/github/VrishankDesaiSLRTCE/Compozent/blob/API-Request/API_Request.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
def get_weather_data(api_key, city_id):
    api_url = "http://api.openweathermap.org/data/2.5/weather"
    params = {
        "id": city_id,
        "units": "metric",
        "appid": api_key
    }
    response = requests.get(api_url, params=params)
    data = response.json()
    if response.status_code == 200:
        return data
    else:
        print(f"Error: {data.get('cod', 'Unknown error')}, Message: {data.get('message', 'Unknown message')}")
        return None
api_key = "YOUR_API_KEY_HERE"
city_id = "524901"
data = get_weather_data(api_key, city_id)
if data:
    print(data)
# Out:
# Error: 401, Message: Invalid API key. Please see https://openweathermap.org/faq#error401 for more info.

# %%
import json
def get_temperature(data):
    temperature = data["main"]["temp"]
    return temperature
if data:
    temperature = get_temperature(data)
    print(f"Temperature: {temperature}°C")

# %%
import requests
def get_weather_data(api_key, city_id):
    api_url = "http://api.openweathermap.org/data/2.5/weather"
    params = {
        "id": city_id,
        "units": "metric",
        "appid": api_key
    }
    response = requests.get(api_url, params=params)
    data = response.json()
    if response.status_code == 200:
        return data
    else:
        print(f"Error: {data.get('cod', 'Unknown error')}, Message: {data.get('message', 'Unknown message')}")
        return None
api_key = "YOUR_API_KEY_HERE"
city_id = "524901"
data = get_weather_data(api_key, city_id)
if data:
    print(data)

    def create_weather_report(data):
        report = "Weather Report:\n"
        city = data["name"]
        report += f"City: {city}\n"
        temperature = data["main"]["temp"]
        report += f"Temperature: {temperature}°C\n"
        humidity = data["main"]["humidity"]
        report += f"Humidity: {humidity}%\n"
        wind_speed = data["wind"]["speed"]
        report += f"Wind Speed: {wind_speed} m/s\n"
        return report

    report = create_weather_report(data)
    print(report)
else:
    print("Could not retrieve weather data. Please check your API key and city ID.")
# Out:
# Error: 401, Message: Invalid API key. Please see https://openweathermap.org/faq#error401 for more info.
# Could not retrieve weather data. Please check your API key and city ID.

# %%
import time
import threading
def get_hourly_weather_data():
    while True:
        data = get_weather_data(api_key, city_id)
        report = create_weather_report(data)
        print(report)
        time.sleep(3600)
thread = threading.Thread(target=get_hourly_weather_data)
thread.start()
# Out:
# Exception in thread Thread-11 (get_hourly_weather_data):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-8-54c4e874a0c6>", line 6, in get_hourly_weather_data
#   File "<ipython-input-6-e5097cd2cecd>", line 3, in create_weather_report
# TypeError: 'NoneType' object is not subscriptable
# Error: 401, Message: Invalid API key. Please see https://openweathermap.org/faq#error401 for more info.
