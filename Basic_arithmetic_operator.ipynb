# %% [markdown]
# <a href="https://colab.research.google.com/github/VrishankDesaiSLRTCE/Compozent/blob/Python-Exercises/Basic_arithmetic_operator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int(input("Enter value of a: "))
b = int(input("Enter value of b: "))
sum = a + b
print(sum)
# Out:
# Enter value of a: 2
# Enter value of b: 4
# 6

# %%
difference = a - b
print(difference)
# Out:
# -2

# %%
product=a*b
print(product)
# Out:
# 8

# %%
division=a/b
print(division)
# Out:
# 0.5
