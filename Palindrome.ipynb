# %% [markdown]
# <a href="https://colab.research.google.com/github/VrishankDesaiSLRTCE/Compozent/blob/Palindrome/Palindrome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def isPalindrome(string):
    if string == string[::-1]:
        return "String is palindrome"
    else:
        return "String is not a palindrome"
string=input("Enter string: ")
print(isPalindrome(string))
# Out:
# Enter string: malayalam
# String is palindrome
